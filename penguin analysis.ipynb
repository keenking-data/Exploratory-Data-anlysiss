# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r"C:\Users\user\Downloads\penguins.csv")

# %%
dataset
# Out:
#      Unnamed: 0    species     island  bill_length_mm  bill_depth_mm  \
# 0             1     Adelie  Torgersen            39.1           18.7
# 1             2     Adelie  Torgersen            39.5           17.4
# 2             3     Adelie  Torgersen            40.3           18.0
# 3             4     Adelie  Torgersen             NaN            NaN
# 4             5     Adelie  Torgersen            36.7           19.3
# ..          ...        ...        ...             ...            ...
# 339         340  Chinstrap      Dream            55.8           19.8
# 340         341  Chinstrap      Dream            43.5           18.1
# 341         342  Chinstrap      Dream            49.6           18.2
# 342         343  Chinstrap      Dream            50.8           19.0
# 343         344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# ...

# %%
dataset.head()
# Out:
#    Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0           1  Adelie  Torgersen            39.1           18.7
# 1           2  Adelie  Torgersen            39.5           17.4
# 2           3  Adelie  Torgersen            40.3           18.0
# 3           4  Adelie  Torgersen             NaN            NaN
# 4           5  Adelie  Torgersen            36.7           19.3
#
#    flipper_length_mm  body_mass_g     sex  year
# 0              181.0       3750.0    male  2007
# 1              186.0       3800.0  female  2007
# 2              195.0       3250.0  female  2007
# 3                NaN          NaN     NaN  2007
# 4              193.0       3450.0  female  2007

# %%
dataset.tail()
# Out:
#      Unnamed: 0    species island  bill_length_mm  bill_depth_mm  \
# 339         340  Chinstrap  Dream            55.8           19.8
# 340         341  Chinstrap  Dream            43.5           18.1
# 341         342  Chinstrap  Dream            49.6           18.2
# 342         343  Chinstrap  Dream            50.8           19.0
# 343         344  Chinstrap  Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 339              207.0       4000.0    male  2009
# 340              202.0       3400.0  female  2009
# 341              193.0       3775.0    male  2009
# 342              210.0       4100.0    male  2009
# 343              198.0       3775.0  female  2009

# %%
dataset.head(8)
# Out:
#    Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0           1  Adelie  Torgersen            39.1           18.7
# 1           2  Adelie  Torgersen            39.5           17.4
# 2           3  Adelie  Torgersen            40.3           18.0
# 3           4  Adelie  Torgersen             NaN            NaN
# 4           5  Adelie  Torgersen            36.7           19.3
# 5           6  Adelie  Torgersen            39.3           20.6
# 6           7  Adelie  Torgersen            38.9           17.8
# 7           8  Adelie  Torgersen            39.2           19.6
#
#    flipper_length_mm  body_mass_g     sex  year
# 0              181.0       3750.0    male  2007
# 1              186.0       3800.0  female  2007
# 2              195.0       3250.0  female  2007
# 3                NaN          NaN     NaN  2007
# 4              193.0       3450.0  female  2007
# 5              190.0       3650.0    male  2007
# 6              181.0       3625.0  female  2007
# ...

# %%
dataset.sample(8)
# Out:
#      Unnamed: 0    species  island  bill_length_mm  bill_depth_mm  \
# 202         203     Gentoo  Biscoe            46.6           14.2
# 296         297  Chinstrap   Dream            42.4           17.3
# 286         287  Chinstrap   Dream            46.6           17.8
# 182         183     Gentoo  Biscoe            47.3           15.3
# 313         314  Chinstrap   Dream            52.0           20.7
# 133         134     Adelie   Dream            37.5           18.5
# 329         330  Chinstrap   Dream            50.7           19.7
# 238         239     Gentoo  Biscoe            43.4           14.4
#
#      flipper_length_mm  body_mass_g  gender  year
# 202              210.0       4850.0  female  2008
# 296              181.0       3600.0  female  2007
# 286              193.0       3800.0  female  2007
# 182              222.0       5250.0    male  2007
# 313              210.0       4800.0    male  2008
# 133              199.0       4475.0    male  2009
# ...

# %%
dataset[200:206]
# Out:
#      Unnamed: 0 species  island  bill_length_mm  bill_depth_mm  \
# 200         201  Gentoo  Biscoe            44.9           13.3
# 201         202  Gentoo  Biscoe            45.2           15.8
# 202         203  Gentoo  Biscoe            46.6           14.2
# 203         204  Gentoo  Biscoe            48.5           14.1
# 204         205  Gentoo  Biscoe            45.1           14.4
# 205         206  Gentoo  Biscoe            50.1           15.0
#
#      flipper_length_mm  body_mass_g  gender  year
# 200              213.0       5100.0  female  2008
# 201              215.0       5300.0    male  2008
# 202              210.0       4850.0  female  2008
# 203              220.0       5300.0    male  2008
# 204              210.0       4400.0  female  2008
# 205              225.0       5000.0    male  2008

# %%
dataset.shape
# Out:
# (344, 9)

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'year'],
#       dtype='object')

# %%
dataset.describe()
# Out:
#        Unnamed: 0  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count  344.000000      342.000000     342.000000         342.000000
# mean   172.500000       43.921930      17.151170         200.915205
# std     99.448479        5.459584       1.974793          14.061714
# min      1.000000       32.100000      13.100000         172.000000
# 25%     86.750000       39.225000      15.600000         190.000000
# 50%    172.500000       44.450000      17.300000         197.000000
# 75%    258.250000       48.500000      18.700000         213.000000
# max    344.000000       59.600000      21.500000         231.000000
#
#        body_mass_g         year
# count   342.000000   344.000000
# mean   4201.754386  2008.029070
# std     801.954536     0.818356
# min    2700.000000  2007.000000
# 25%    3550.000000  2007.000000
# 50%    4050.000000  2008.000000
# 75%    4750.000000  2009.000000
# max    6300.000000  2009.000000

# %%
dataset.describe(include="all")
# Out:
#         Unnamed: 0 species  island  bill_length_mm  bill_depth_mm  \
# count   344.000000     344     344      342.000000     342.000000
# unique         NaN       3       3             NaN            NaN
# top            NaN  Adelie  Biscoe             NaN            NaN
# freq           NaN     152     168             NaN            NaN
# mean    172.500000     NaN     NaN       43.921930      17.151170
# std      99.448479     NaN     NaN        5.459584       1.974793
# min       1.000000     NaN     NaN       32.100000      13.100000
# 25%      86.750000     NaN     NaN       39.225000      15.600000
# 50%     172.500000     NaN     NaN       44.450000      17.300000
# 75%     258.250000     NaN     NaN       48.500000      18.700000
# max     344.000000     NaN     NaN       59.600000      21.500000
#
#         flipper_length_mm  body_mass_g   sex         year
# count          342.000000   342.000000   333   344.000000
# ...

# %%
dataset.drop("Unnamed: 0", axis = 1)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
#option1
dataset=dataset.drop(columns=["Unnamed: 0"])

# %%
dataset.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
dataset.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
dataset=dataset.drop(columns=["species", "sex","island"])

# %%
dataset.head()
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  year
# 0            39.1           18.7              181.0       3750.0  2007
# 1            39.5           17.4              186.0       3800.0  2007
# 2            40.3           18.0              195.0       3250.0  2007
# 3             NaN            NaN                NaN          NaN  2007
# 4            36.7           19.3              193.0       3450.0  2007

# %%
dataset.drop(1, axis = 0, inplace= True)data

# %%
dataset.drop(3, axis = 0, inplace= True)

# %%
da6ts

# %%
dataset.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen            36.7           18.0                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g  gender  year
# 0       3750.0    male  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007
# 5       3650.0    male  2007

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 343 entries, 0 to 343
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   bill_length_mm     342 non-null    float64
#  1   bill_depth_mm      342 non-null    float64
#  2   flipper_length_mm  342 non-null    float64
#  3   body_mass_g        342 non-null    float64
#  4   year               343 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 16.1 KB

# %%
dataset["bill_length_mm"].isnull().sum()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize =(10, 6))
sns.heatmap(dataset.isnull())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 plt.figure(figsize =(10, 6))
# ----> 2 sns.heatmap(dataset.isnull())
#
# NameError: name 'dataset' is not defined

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0            0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
dataset.drop("Unnamed: 0", axis =1, inplace=True)

# %%
dataset.bill_depth_mm.mean()
# Out:
# 17.151169590643274

# %%
import numpy as np
np.mean(dataset.bill_depth_mm)
# Out:
# 17.151169590643274

# %%
dataset.bill_depth_mm.fillna(17.2)
# Out:
# 0      18.7
# 1      17.4
# 2      18.0
# 3      17.2
# 4      19.3
#        ...
# 339    19.8
# 340    18.1
# 341    18.2
# 342    19.0
# 343    18.7
# Name: bill_depth_mm, Length: 344, dtype: float64

# %%
dataset.bill_depth_mm = dataset.bill_depth_mm.fillna(17.2)

# %%
dataset.bill_depth_mm.isnull().sum()
# Out:
# 0

# %%
dataset.bill_depth_mm.mode()
# Out:
# 0    17.0
# Name: bill_depth_mm, dtype: float64

# %%
dataset.bill_depth_mm = dataset.bill_depth_mm.fillna(17.0)

# %%
dataset.flipper_length_mm.median()
# Out:
# 197.0

# %%
dataset.flipper_length_mm=dataset.flipper_length_mm.fillna(197.0)

# %%
dataset.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN           17.2              197.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
dataset.sex.mode()
# Out:
# 0    male
# Name: sex, dtype: object

# %%
dataset.sex=dataset.sex.fillna("male")

# %%
dataset.sex.isnull().sum()
# Out:
# 0

# %%
import warnings 
warnings.filterwarnings('ignore')
dataset.bill_length_mm = dataset.bill_length_mm.fillna(method = "bfill")

# %%
dataset.head()
# Out:
#    Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0           1  Adelie  Torgersen            39.1           18.7
# 1           2  Adelie  Torgersen            39.5           17.4
# 2           3  Adelie  Torgersen            40.3           18.0
# 3           4  Adelie  Torgersen            36.7            NaN
# 4           5  Adelie  Torgersen            36.7           19.3
#
#    flipper_length_mm  body_mass_g     sex  year
# 0              181.0       3750.0    male  2007
# 1              186.0       3800.0  female  2007
# 2              195.0       3250.0  female  2007
# 3                NaN          NaN     NaN  2007
# 4              193.0       3450.0  female  2007

# %%
import warnings 
warnings.filterwarnings('ignore')
dataset.bill_depth_mm = dataset.bill_depth_mm.fillna(method = "ffill")

# %%
dataset.head()
# Out:
#    Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0           1  Adelie  Torgersen            39.1           18.7
# 1           2  Adelie  Torgersen            39.5           17.4
# 2           3  Adelie  Torgersen            40.3           18.0
# 3           4  Adelie  Torgersen            36.7           18.0
# 4           5  Adelie  Torgersen            36.7           19.3
#
#    flipper_length_mm  body_mass_g     sex  year
# 0              181.0       3750.0    male  2007
# 1              186.0       3800.0  female  2007
# 2              195.0       3250.0  female  2007
# 3                NaN          NaN     NaN  2007
# 4              193.0       3450.0  female  2007

# %%
dataset.rename({"sex":"gender"},axis = 1, inplace=True)
dataset.head()
# Out:
#    Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0           1  Adelie  Torgersen            39.1           18.7
# 1           2  Adelie  Torgersen            39.5           17.4
# 2           3  Adelie  Torgersen            40.3           18.0
# 3           4  Adelie  Torgersen            36.7           18.0
# 4           5  Adelie  Torgersen            36.7           19.3
#
#    flipper_length_mm  body_mass_g  gender  year
# 0              181.0       3750.0    male  2007
# 1              186.0       3800.0  female  2007
# 2              195.0       3250.0  female  2007
# 3                NaN          NaN     NaN  2007
# 4              193.0       3450.0  female  2007

# %%
import seaborn as sns

# %%
sns.countplot(x ='species',data= dataset, hue = "sex")
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.countplot(x ='species',data= dataset, hue = "island")
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.countplot(x ='',data= dataset)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x ='island',data= dataset)
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %%
sns.boxplot(x ="species", y="body_mass_g", data=dataset)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.boxplot(x ="species", y="body_mass_g", data=dataset, hue="sex")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.boxplot(x ="species", y="flipper_length_mm", data=dataset, hue="island")
# Out:
# <Axes: xlabel='species', ylabel='flipper_length_mm'>

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'year'],
#       dtype='object')

# %%
plt.figure(figsize=(14, 10))
plt.title("Bar plot of bill_lenghth_mm per species", font="simsun", fontsize =14)
plt.xlabel("Species")
sns.set_style("darkgrid")
sns.barplot(x='species',y='bill_length_mm',data=dataset, hue = 'island')
# Out:
# <Axes: title={'center': 'Bar plot of bill_lenghth_mm per species'}, xlabel='Species', ylabel='bill_length_mm'>

# %%
plt.figure(figsize=(14, 10))
sns.catplot(x="island", y="body_mass_g", data=dataset, hue="sex",dodge=True)

# %%
plt.figure(figsize=(14, 10))
sns.violinplot(x="island", y="body_mass_g", data=dataset, hue="sex", split=True)
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
plt.figure(figsize=(14, 10))
sns.histplot(dataset["bill_length_mm"], kde =True)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
plt.figure(figsize=(14, 10))
sns.kdeplot(dataset["bill_length_mm"])
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Density'>

# %%
plt.figure(figsize=(14,10))
sns.scatterplot(x="flipper_length_mm", y="body_mass_g", data=dataset, hue="sex")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
plt.figure(figsize=(14,10))
sns.relplot(y="bill_length_mm", x="body_mass_g", data=dataset ,hue="sex", kind="line")

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'year'],
#       dtype='object')

# %%
x=[2, 4, 6, 8, 10, 12, 14, 16]
y=[7, 9, 11, 13, 15, 17, 19,21]
plt
plt.title("sample plot")
plt.xlabel("")
plt.ylabel("")
plt.show()
